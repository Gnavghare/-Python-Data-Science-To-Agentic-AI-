# %% [markdown]
# # Sequence Category DataTypes
#
# ### The purpose of Sequence Category DataTypes is that "To Store Sequence of Values."
#
# ### We have 4 datatypes in Sequence Category.Theyare***
#
# i)str
#
# ii)bytes
#
# iii)bytearray
#
#  iv)range

# %% [markdown]
# # String

# %%
s = welcome team
# Out:
#   Cell In[1], line 1
#     s = welcome team
#                 ^
# SyntaxError: invalid syntax

# %%
s = 'welcome team' # single quotes 
s
# Out:
# 'welcome team'

# %%
s1 = "welcome team" # double quotes 
s1
# Out:
# 'welcome team'

# %%
s2 = ''' welcome team'''  # Triple quotes 
s2
# Out:
# ' welcome team'

# %%
s3 = 'welcome to python fundamentals
       under gaurav navghare guidance'
s3
# Out:
#   Cell In[8], line 1
#     s3 = 'welcome to python fundamentals
#          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s4 = "welcome to python fundamentals
       under gaurav navghare guidance'
s4
# Out:
#   Cell In[9], line 1
#     s4 = "welcome to python fundamentals
#          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s5 = '''welcome to python fundamentals
       under gaurav navghare guidance'''
s5
# Out:
# 'welcome to python fundamentals\n       under gaurav navghare guidance'

# %% [markdown]
# # string indexing

# %%
si = 'welcome'
si
# Out:
# 'welcome'

# %%
si[0] # first character of string
# Out:
# 'w'

# %%
s[4] # fifth character of string
# Out:
# 'o'

# %%
si[6] # seventh character of string
# Out:
# 'e'

# %%
si[7] # eighth character of string
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 si[7] # eighth character of string
#
# IndexError: string index out of range

# %%
si[10] # eleventh character of string
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 si[10] # eleventh character of string
#
# IndexError: string index out of range

# %%
si[-1]
# Out:
# 'e'

# %%
si[-2] # second last character of string
# Out:
# 'm'

# %%
si[-7] # seventh last character of string
# Out:
# 'w'

# %%
si[-1000] # IndexError: string index out of range
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 si[-1000] # IndexError: string index out of range
#
# IndexError: string index out of range

# %% [markdown]
# ### forward index & backward index & Indexing error

# %%
si
# Out:
# 'welcome'

# %%
si[:] # all characters of string
# Out:
# 'welcome'

# %%
si[1:4] # second to fourth character of string
# Out:
# 'elc'

# %%
si[0:6] # first to sixth character of string
# Out:
# 'welcom'

# %%
si[3:7] # fourth to seventh character of string
# Out:
# 'come'

# %%
si[10] # eleventh character of string
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 si[10] # eleventh character of string
#
# IndexError: string index out of range

# %%
si[3:10] # fourth to tenth character of string
# Out:
# 'come'

# %%
si[4:100] # fourth to hundredth character of string
# Out:
# 'ome'

# %%
si
# Out:
# 'welcome'

# %%
si[1:] # slicing from second character to end of string
# Out:
# 'elcome'

# %%
s[3:] # slicing from fourth character to end of string
# Out:
# 'come team'

# %%
si[:] # all characters of string
# Out:
# 'welcome'

# %%
si[:6] # first to sixth character of string
# Out:
# 'welcom'

# %%
si[:4] # first to fourth character of string
# Out:
# 'welc'

# %% [markdown]
# ## step slicing

# %%
si[0:7:2] # first to seventh character of string with step 2
# Out:
# 'wloe'

# %%
si[0:7:4] # first to seventh character of string with step 4
# Out:
# 'wo'

# %%
si[-5:-1] # slicing from fifth last character to second last character of string
# Out:
# 'lcom'

# %%
si[::2] # slicing from first character to end of string with step 2
# Out:
# 'wloe'

# %%
si[::3] # slicing from first character to end of string with step 3
# Out:
# 'wce'

# %%
si[::-1] # slicing from last character to first character of string with step -1
# Out:
# 'emoclew'

# %%
si[::-2] # slicing from last character to first character of string with step -2
# Out:
# 'eolw'

# %% [markdown]
# ##### string indexing, slicing, forward slicing, backward slicing, step slicing, advance slicing ......  All completed

# %% [markdown]
# # Python type casting

# %%
10.34
# Out:
# 10.34

# %% [markdown]
# # other type to int

# %%
int(10.34) # we can convert float to int
# Out:
# 10

# %%
int(True) # boolean to int possible
# Out:
# 1

# %%
int(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 int(1+2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('10')
# Out:
# 10

# %%
int('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 int('ten')
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %% [markdown]
# ### in type casting while typecast from all other datatype to int possible except complex & text string

# %% [markdown]
# # other datatype to float

# %%
float(110)# we can convert int to float
# Out:
# 110.0

# %%
float(True)  # boolean to float possible

# %%
float(False)  # boolean to float possible
# Out:
# 0.0

# %%
float(false) # error: name 'false' is not defined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 float(false) # error: name 'false' is not defined
#
# NameError: name 'false' is not defined

# %%
float(1+2j)  # complex to float  not possible
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 float(1+2j)  # complex to float  not possible
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float('10')  # number string
# Out:
# 10.0

# %%
float('ten') #text string to float (error)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 float('ten') #text string to float (error)
#
# ValueError: could not convert string to float: 'ten'

# %% [markdown]
# # other datatype to boolean

# %%
bool(2)  # int to boolean possible
# Out:
# True

# %%
bool(0)#  # int to boolean possible
# Out:
# False

# %%
bool(2.3) # float to boolean possible
# Out:
# True

# %%
bool(1+2j)  # complex to boolean possible
# Out:
# True

# %%
bool('10')  # string to boolean possible
# Out:
# True

# %%
bool('ten') # text string to boolean (True)
# Out:
# True

# %%
bool() # Returns False
# Out:
# False

# %%
bool(-2) # Returns True
# Out:
# True

# %% [markdown]
# # all other datatype to complex

# %%
complex(2) # int to complex possible
# Out:
# (2+0j)

# %%
complex(3, 4) # int to complex with real and imaginary parts
# Out:
# (3+4j)

# %%
complex(3,4,5) # int to complex with real, imaginary and additional argument (error)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 complex(3,4,5) # int to complex with real, imaginary and additional argument (error)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex(2.3)  # float to complex possible
# Out:
# (2.3+0j)

# %%
complex(2.3, 4.5) # float to complex with real and imaginary parts possible
# Out:
# (2.3+4.5j)

# %%
complex(True) # boolean to complex possible
# Out:
# (1+0j)

# %%
complex(False) # boolean to complex possible
# Out:
# 0j

# %%
complex('10') # string to complex possible
# Out:
# (10+0j)

# %%
complex('ten')# TypeError: complex() arg is a malformed string
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 complex('ten')# TypeError: complex() arg is a malformed string
#
# ValueError: complex() arg is a malformed string

# %%
complex('10', '20') # TypeError: complex() takes at most 2 arguments (3 given)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 complex('10', '20') # TypeError: complex() takes at most 2 arguments (3 given)
#
# TypeError: complex() argument 'real' must be a real number, not str

# %%
complex(10, '20') # TypeError: complex() can't take second arg if first is a string
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 complex(10, '20') # TypeError: complex() can't take second arg if first is a string
#
# TypeError: complex() argument 'imag' must be a real number, not str

# %%
str(10)
# Out:
# '10'

# %%
str(10.4) # '10.4'
# Out:
# '10.4'

# %%
str(True) # 'True'
str(False) # 'False'
# Out:
# 'False'

# %%
str(1+2j)
# Out:
# '(1+2j)'

# %% [markdown]
# ## python type casting we are completed
