# %% [markdown]
# #### WELCOME TO FSDS_GENAI_AGENTIC AI PROGRAMME_ Gaurav Navghare

# %% [markdown]
# # DataTypes in Python
# ### The main purpose of datatypes is that To allocate sufficient amount of memory space for input of the program.
# ## In Python Programming,
# ## we have 14 datatypes and they are classfied into 6types.
# **I)Fundamental Category DataTypes**
#
#   a)int
#
#   b)float
#
#   c)bool
#
#   d)complex
#
# ### II)Sequence Category DataTypes:
#
#    a)str
#
#    b)bytes
#
#    c)bytearray
#
#    d)range
# ### III )List Category DataTypes(Collections DataType)
#
# a)list
#
# b)tuple
#
# ### IV)Set Category DataTypes(Collections DataType)
#
# a)set
#
# b)frozenset
#
# ### V)Dict Category DataTypes(Collections DataType)
#
# a)dict
#
# ### VI)None Category DataType
#
# a)NoneType

# %% [markdown]
# # int

# %%
i = 5 
i
# Out:
# 5

# %%
type()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 type()
#
# TypeError: type() takes 1 or 3 arguments

# %%
type(i)
# Out:
# int

# %%
i
# Out:
# 5

# %%
id(i)
# Out:
# 140713097340152

# %%
age = 24 
age
# Out:
# 24

# %%
print(type(age))
print(id(age))
# Out:
# <class 'int'>
# 140713097340760

# %% [markdown]
# # float

# %%
f = 110.23
f
# Out:
# 110.23

# %%
type(f)
# Out:
# float

# %%
id(f)
# Out:
# 2293695567056

# %%
print(i)
print(f)
# Out:
# 5
# 110.23

# %% [markdown]
# # bool

# %%
b = true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 b = true
#
# NameError: name 'true' is not defined

# %%
b = True
b
# Out:
# True

# %%
type(b)
# Out:
# bool

# %%
b1 = False
b1
# Out:
# False

# %%
type(b1)
# Out:
# bool

# %%
p = 20
q = 20

# %%
p, q = 20, 20

# %%
print(id(p))
print(id(q))
# Out:
# 140713097340632
# 140713097340632

# %%
print(p)
print(q)
# Out:
# 20
# 20

# %%
p = p + 10
p
# Out:
# 40

# %%
print(p)
print(q)
# Out:
# 40
# 20

# %%
print(id(p))
print(id(q))
# Out:
# 140713097341272
# 140713097340632

# %%
print(b)
print(b1)
# Out:
# True
# False

# %%
b
# Out:
# True

# %%
b1
# Out:
# False

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True + False
# Out:
# 1

# %%
True * False
# Out:
# 0

# %%
False * True
# Out:
# 0

# %%
False / True
# Out:
# 0.0

# %%
10/2
# Out:
# 5.0

# %%
10//2
# Out:
# 5

# %%
False // True
# Out:
# 0

# %% [markdown]
# # complex

# %%
c = 10 + 20j 
c
# Out:
# (10+20j)

# %%
type(c)
# Out:
# complex

# %%
c1 = 20+30J
c1
# Out:
# (20+30j)

# %%
print(c)
print(c1)
# Out:
# (10+20j)
# (20+30j)

# %%
c
# Out:
# (10+20j)

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0

# %%
print(c)
print(c1)
# Out:
# (10+20j)
# (20+30j)

# %%
c + c1
# Out:
# (30+50j)
