# %% [markdown]
# # LIST DATASTRUCTURE

# %% [markdown]
# ### PYTHON DATA STRUCTURE ( TASK - 2)

# %% [markdown]
# * LIST DATASTRUCTURE -
#
# * Insertation order is preserved & duplicates are allowed
# * if you want to represent group of values as a singel entity where insertation   order is preserved and duplicates are allowed   then we can go for LIST datatype
# * what is the meaning of insertaion order is preserved
# * you can increase the least object or you can decrease the list object
# * list you can use index operator and also slice operator

# %%
l = [] #empty list
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %%
l.append(10)
l
# Out:
# [10]

# %%
len(l)
# Out:
# 1

# %%
l.append(20, 30, 40)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 l.append(20, 30, 40)
#
# TypeError: list.append() takes exactly one argument (3 given)

# %%
l
# Out:
# [10]

# %%
l.append(20)
l.append(30)
l.append(40)
l.append(50)
l
# Out:
# [10, 20, 30, 40, 50]

# %%
len(l)
# Out:
# 5

# %%
l
# Out:
# [10, 20, 30, 40, 50]

# %%
l.append(10) 
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l1 = [10, 3.5, True, 1+2j, 'welcome'] 
l1
# Out:
# [10, 3.5, True, (1+2j), 'welcome']

# %%
l1.append([1,2,3]) # nested list 
l1
# Out:
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 l3
#
# NameError: name 'l3' is not defined

# %%
l3 = l.copy()
l3
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
print(l)
print(l1)
print(l3)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]
# [10, 20, 30, 40, 50, 10]

# %%
l == l3
# Out:
# True

# %%
len(l) == len(l3)
# Out:
# True

# %%
id(l) == id(l3)
# Out:
# False

# %%
id(l) != id(l3)
# Out:
# True

# %%
print(id(l))
print(id(l3))
# Out:
# 2794041982400
# 2794057780736

# %%
print(l)
print(l1)
print(l3)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]
# [10, 20, 30, 40, 50, 10]

# %%
l3.clear()

# %%
print(l)
print(l1)
print(l3)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 3.5, True, (1+2j), 'welcome']
# []

# %%
del l3

# %%
l3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 l3
#
# NameError: name 'l3' is not defined

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l.count(30)
# Out:
# 1

# %%
l.count(10)
# Out:
# 2

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
l.extend(l1) 
l
# Out:
# [10, 20, 30, 40, 50, 10, 10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
print(len(l))
print(len(l1))
# Out:
# 12
# 6

# %%
a1 = [1,2,3]
b1 = [4,5,6]

# %%
a1.extend(b1)
a1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
print(a1)
print(b1)
# Out:
# [1, 2, 3, 4, 5, 6]
# [4, 5, 6]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 10, 10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
l.index(20)
# Out:
# 1

# %%
l1
# Out:
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
l1.index(1+2j)
# Out:
# 3

# %%
l1.index('welcome')
# Out:
# 4

# %%
l1
# Out:
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
l1[:]
# Out:
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
l1[5]
# Out:
# [1, 2, 3]

# %%
l1
# Out:
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
l1[4]
# Out:
# 'welcome'

# %%
l1
# Out:
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
l1[:3]
# Out:
# [10, 3.5, True]

# %%
l1
# Out:
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
l1[3:]
# Out:
# [(1+2j), 'welcome', [1, 2, 3]]

# %%
l1
# Out:
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
l1[0:5:2]
# Out:
# [10, True, 'welcome']

# %%
l1
# Out:
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
l1[-3]
# Out:
# (1+2j)

# %%
l1[-3:]
# Out:
# [(1+2j), 'welcome', [1, 2, 3]]

# %%
l1
# Out:
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
l1[::-1]
# Out:
# [[1, 2, 3], 'welcome', (1+2j), True, 3.5, 10]

# %%
l1
# Out:
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
l1[::-2]
# Out:
# [[1, 2, 3], (1+2j), 3.5]

# %%
l1
# Out:
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
l1[4]
# Out:
# 'welcome'

# %%
print(l1[4][0])
print(l1[4][1])
print(l1[4][2])
print(l1[4][3])
print(l1[4][4])
print(l1[4][5])
print(l1[4][6])
print(l1[4][7])
# Out:
# w
# e
# l
# c
# o
# m
# e
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[66], line 8
#       6 print(l1[4][5])
#       7 print(l1[4][6])
# ----> 8 print(l1[4][7])
#
# IndexError: string index out of range

# %%
l1
# Out:
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
l1[0]
# Out:
# 10

# %%
l1[0] = 100

# %%
l1
# Out:
# [100, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
l1.pop(1)
l1
# Out:
# [100, (1+2j), 'welcome', [1, 2, 3]]

# %%
l1.

# %%
l=[10, 20, 30, 10, 10, 20, 30, 10, 8.0, None, (1+2j), True]

# %%
l
# Out:
# [10, 20, 30, 10, 10, 20, 30, 10, 8.0, None, (1+2j), True]

# %%
l[:] # : --> this will give us total values which we passed in the object
# Out:
# [10, 20, 30, 10, 10, 20, 30, 10, 8.0, None, (1+2j), True]

# %%
l.pop(6)
# Out:
# 30

# %%
l
# Out:
# [10, 20, 30, 10, 10, 20, 10, 8.0, None, (1+2j), True]

# %%
del l[-2]

# %%
l
# Out:
# [10, 20, 30, 10, 10, 20, 10, 8.0, None, True]

# %%
l[:-1] 
l
# Out:
# [10, 20, 30, 10, 10, 20, 10, 8.0, None, True]

# %%
a, b, c = [1, 'nit', [1,2,3]]

# %%
a
# Out:
# 1

# %%
b
# Out:
# 'nit'

# %%
c
# Out:
# [1, 2, 3]

# %%
a1, b1, c1 = [1, 'nit', [1,2,3]]

# %%
a1
# Out:
# 1

# %%
b1
# Out:
# 'nit'

# %%
l2 = [a1,b1,c1]
l2
# Out:
# [1, 'nit', [1, 2, 3]]

# %%
print(l)
l[::-1] # reverse order
# Out:
# [10, 20, 30, 10, 10, 20, 10, 8.0, None, True]
# [True, None, 8.0, 10, 20, 10, 10, 30, 20, 10]

# %%
l.remove(8.0) 
l
# Out:
# [10, 20, 30, 10, 10, 20, 10, None, True]

# %%
l.remove('7')
l
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 l.remove('7')
#       2 l
#
# ValueError: list.remove(x): x not in list

# %%
print(l)
l[:-3] # starting index to ending with -3 index
# Out:
# [10, 20, 30, 10, 10, 20, 10, None, True]
# [10, 20, 30, 10, 10, 20]
